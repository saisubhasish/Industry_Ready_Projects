# %% [markdown]
# Assignment 1:
# - Demonstrate minimum 15 basic docker command with explanation and screenshot.

# %% [markdown]
# To initialize git to your project
# **git init**

# %%
from IPython import display
display.Image("Screenshot_28.png")

# %% [markdown]
# To check user configuration **git remote -v**

# %%
from IPython import display
display.Image("Screenshot_29.png")

# %% [markdown]
# To add user config **git config --global user.name "your_name"**,
# **git config --global user.email "sample@gmail.com"**

# %%
from IPython import display
display.Image("Screenshot_30.png")

# %% [markdown]
# To add all files to stagging area in current directory **git add .**

# %%
from IPython import display
display.Image("Screenshot_31.png")

# %% [markdown]
# To commit **git commit -m "commit message"**

# %%
from IPython import display
display.Image("Screenshot_32.png")

# %% [markdown]
# Adding specific files to the staging  **git add file_name**

# %%
from IPython import display
display.Image("Screenshot_33.png")

# %% [markdown]
# Adding multiple files to stagging **git add file_name1 file_name2**

# %%
from IPython import display
display.Image("Screenshot_34.png")

# %% [markdown]
# To list changes that you’ve made but not yet added in stagging or committed **git status**

# %%
from IPython import display
display.Image("Screenshot_35.png")

# %% [markdown]
# Alternatively, instead of running git add
#  beforehand, you can use
#
# **git commit -a**
#
# which will automatically notice any modified (but not new) files, add them to the
# index, and commit, all in one step.

# %%
from IPython import display
display.Image("Screenshot_36.png")

# %% [markdown]
# Viewing project history or all the logs **git log**

# %%
from IPython import display
display.Image("Screenshot_37.png")

# %% [markdown]
# If you also want to see complete diffs at each step, use **git log -p**

# %%
from IPython import display
display.Image("Screenshot_38.png")

# %% [markdown]
# To list the overview of the change **git log --stat --summary**

# %%
from IPython import display
display.Image("Screenshot_39.png")

# %% [markdown]
# To create a new branch named "branch_name", use **git branch branch_name**

# %%
from IPython import display
display.Image("Screenshot_40.png")

# %% [markdown]
# To list all branches **git branch**

# %%
from IPython import display
display.Image("Screenshot_41.png")

# %% [markdown]
# To start working on another branch you can switch branches using the below command **git switch branch_name**

# %%
from IPython import display
display.Image("Screenshot_42.png")

# %% [markdown]
# To bring changes into the master branch you have to merge your created branch
# with the master using the below command **git merge branch_name**

# %%
from IPython import display
display.Image("Screenshot_43.png")

# %% [markdown]
# To see all commit history using nice graph representation **git log --graph**

# %%
from IPython import display
display.Image("Screenshot_44.png")

# %% [markdown]
# To delete the branch **git branch -d branch_name**

# %%
from IPython import display
display.Image("Screenshot_45.png")

# %% [markdown]
# Clone a repo **git clone repo_url**

# %%
from IPython import display
display.Image("Screenshot_46.png")

# %% [markdown]
# Now change your directory to the newly cloned repo **cd path_to_cloned_repo**

# %%
from IPython import display
display.Image("Screenshot_47.png")

# %% [markdown]
# Now make any changes and commit it **git commit -a -m "commit_message"**

# %% [markdown]
# Push a repo  **git push origin "branch_name"**

# %% [markdown]
# git pull bring changes from remote repo into local and merge the change into your
# local repo **git pull**

# %% [markdown]
# git fetch bring changes from remote repo and allow us to review and resolve any
# conflict and after that we can manually commit the new changes  **git fetch**,
# **git merge**
